# %%
while(True):
    try:
            name=input("請輸入姓名:")
            print(f"請輸入姓名:{name}")
            weight=eval(input("請輸入體重(公斤):"))
            print(f"請輸入身高(cm):{height}")
            height=eval(input("請輸入身高(公分):"))
            BMI = weight / ((height/100)**2)
            print(f"請輸入體重(kg):{weight}")

    
            if(BMI<18.5):
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:體重過輕")
            elif(18.5<=BMI<24):
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:正常範圍")
            elif(24<=BMI<27):
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:過重")
            elif(27<=BMI<30):
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:輕度肥胖")
            elif(30<=BMI<35):
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:中度肥胖")
            else:
                        print(f"{name}的BMI{BMI:.2f}")
                        print(f"{name}的體重:重度肥胖")
        
    except Exception: 
        print("格式錯誤,請重新輸入:")
        print("=================")
        continue
    value=input("要繼續輸入嗎")
    print(f"要繼續輸入嗎(y繼續,n中斷):{value}")
    print("=================")
        
    if value.upper() =="Y"  :  
        continue
        
    if value.upper() == "N" :
        break
print("程式結束")
# Out:
# 請輸入姓名:林睿煌
# 請輸入身高(cm):12
# 請輸入體重(kg):60
# 林睿煌的BMI20.76
# 林睿煌的體重:正常範圍
# 要繼續輸入嗎(y繼續,n中斷):y
# =================
# 請輸入姓名:林睿煌
# 請輸入身高(cm):170
# 請輸入體重(kg):80
# 林睿煌的BMI22.16
# 林睿煌的體重:正常範圍
# 要繼續輸入嗎(y繼續,n中斷):y
# =================
# 請輸入姓名:林睿煌
# 請輸入身高(cm):190
# 格式錯誤,請重新輸入:
# =================
# 請輸入姓名:林睿煌
# 請輸入身高(cm):190
# 請輸入體重(kg):80
# 林睿煌的BMI35.56
# 林睿煌的體重:重度肥胖
# 要繼續輸入嗎(y繼續,n中斷):n
# =================
# 程式結束

# %%
def answer()->None:

    while(True):
        answer()
        name=input("請輸入姓名:")
        print(f"請輸入姓名:{name}")
        weight=eval(input("請輸入體重(公斤):"))
        print(f"請輸入身高(cm):{height}")
        height=eval(input("請輸入身高(公分):"))
        BMI = weight / ((height/100)**2)
        print(f"請輸入體重(kg):{weight}")

        
        if(BMI<18.5):
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:體重過輕")
        elif(18.5<=BMI<24):
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:正常範圍")
        elif(24<=BMI<27):
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:過重")
        elif(27<=BMI<30):
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:輕度肥胖")
        elif(30<=BMI<35):
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:中度肥胖")
        else:
            print(f"{name}的BMI{BMI:.2f}")
            print(f"{name}的體重:重度肥胖")

    answer()  
    answer=input(" 要繼續輸入嗎(y繼續,n中斷):")
    print(f"要繼續輸入嗎(y繼續,n中斷):{answer}")
    print("=================")
    if answer.upper() =="N":
        print("格式錯誤,請重新輸入:")
        print("=================")
        break
print("程式結束")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[8], line 33
#      31             print(f"{name}的體重:重度肥胖")
#      32 while(True):
# ---> 33     answer()
#      34     answer=input(" 要繼續輸入嗎(y繼續,n中斷):")
#      35     print(f"要繼續輸入嗎(y繼續,n中斷):{answer}")
#
# Cell In[8], line 4, in answer()
#       1 def answer()->None:
# ----> 4         answer()
#       5         name=input("請輸入姓名:")
#       6         print(f"請輸入姓名:{name}")
#
# Cell In[8], line 4, in answer()
#       1 def answer()->None:
# ----> 4         answer()
#       5         name=input("請輸入姓名:")
#       6         print(f"請輸入姓名:{name}")
#
#     [... skipping similar frames: answer at line 4 (2969 times)]
#
# Cell In[8], line 4, in answer()
#       1 def answer()->None:
# ----> 4         answer()
#       5         name=input("請輸入姓名:")
#       6         print(f"請輸入姓名:{name}")
#
# RecursionError: maximum recursion depth exceeded
